# %%
k=seq(0.001,40,0.01)
plot(k,0.3*exp(-k/5),'l',ylim=c(0,0.1))
lines(k,1/(0.5^2+k^2)^0.9,'l',col="blue")
lines(k,1/(0.3^2+k^2)^1.1,'l',col="red")
# Out:
# plot without title

# %%
k=seq(0.001,40,0.01)
plot(k,0.3*exp(-k/5),'l',ylim=c(0,0.1))
lines(k,1/(0.5^2+k^2)^0.9,'l',col="blue")
lines(k,1/(0.7^2+k^2)^0.9,'l',col="red")
lines(k,1/(0.9^2+k^2)^0.9,'l',col="yellow")
# Out:
# plot without title
